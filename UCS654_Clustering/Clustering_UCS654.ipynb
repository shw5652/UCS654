# %%
#!pip install pycaret &> /dev/null

# %%
# from pycaret.utils import version
# version()

# %%
# !pip install ucimlrepo

# %%
import pandas as pd
import numpy as np

# %%
from ucimlrepo import fetch_ucirepo

wholesale_customers = fetch_ucirepo(id=292)

# %%
df = wholesale_customers.data

# %%
df
# Out:
# {'ids': None,
#  'features':      Channel  Fresh   Milk  Grocery  Frozen  Detergents_Paper  Delicassen
#  0          2  12669   9656     7561     214              2674        1338
#  1          2   7057   9810     9568    1762              3293        1776
#  2          2   6353   8808     7684    2405              3516        7844
#  3          1  13265   1196     4221    6404               507        1788
#  4          2  22615   5410     7198    3915              1777        5185
#  ..       ...    ...    ...      ...     ...               ...         ...
#  435        1  29703  12051    16027   13135               182        2204
#  436        1  39228   1431      764    4510                93        2346
#  437        2  14531  15488    30243     437             14841        1867
#  438        1  10290   1981     2232    1038               168        2125
#  439        1   2787   1698     2510      65               477          52
#
#  [440 rows x 7 columns],
#  'targets':      Region
#  0         3
#  1         3
#  2         3
#  3         3
#  4         3
#  ..      ...
#  435       3
#  436       3
#  437       3
#  438       3
#  439       3
#
#  [440 rows x 1 columns],
#  'original':      Channel  Region  Fresh   Milk  Grocery  Frozen  Detergents_Paper  \
#  0          2       3  12669   9656     7561     214              2674
#  1          2       3   7057   9810     9568    1762              3293
#  2          2       3   6353   8808     7684    2405              3516
#  3          1       3  13265   1196     4221    6404               507
#  4          2       3  22615   5410     7198    3915              1777
#  ..       ...     ...    ...    ...      ...     ...               ...
#  435        1       3  29703  12051    16027   13135               182
#  436        1       3  39228   1431      764    4510                93
#  437        2       3  14531  15488    30243     437             14841
#  438        1       3  10290   1981     2232    1038               168
#  439        1       3   2787   1698     2510      65               477
#
#       Delicassen
#  0          1338
#  1          1776
#  2          7844
#  3          1788
#  4          5185
#  ..          ...
#  435        2204
#  436        2346
#  437        1867
#  438        2125
#  439          52
#
#  [440 rows x 8 columns],
#  'headers': Index(['Channel', 'Region', 'Fresh', 'Milk', 'Grocery', 'Frozen',
#         'Detergents_Paper', 'Delicassen'],
#        dtype='object')}

# %%
data=pd.read_csv("/content/Wholesale customers data.csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 440 entries, 0 to 439
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Channel           440 non-null    int64
#  1   Region            440 non-null    int64
#  2   Fresh             440 non-null    int64
#  3   Milk              440 non-null    int64
#  4   Grocery           440 non-null    int64
#  5   Frozen            440 non-null    int64
#  6   Detergents_Paper  440 non-null    int64
#  7   Delicassen        440 non-null    int64
# dtypes: int64(8)
# memory usage: 27.6 KB

# %%
data.head()
# Out:
#    Channel  Region  Fresh  Milk  Grocery  Frozen  Detergents_Paper  Delicassen
# 0        2       3  12669  9656     7561     214              2674        1338
# 1        2       3   7057  9810     9568    1762              3293        1776
# 2        2       3   6353  8808     7684    2405              3516        7844
# 3        1       3  13265  1196     4221    6404               507        1788
# 4        2       3  22615  5410     7198    3915              1777        5185

# %%
from pycaret.clustering import *
kMeanClusteringParameters = setup(data)
# Out:
# <style type="text/css">
# #T_4710f_row4_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_4710f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4710f_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_4710f_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4710f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4710f_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_4710f_row0_col1" class="data row0 col1" >1124</td>
#     </tr>
#     <tr>
#       <th id="T_4710f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4710f_row1_col0" class="data row1 col0" >Original data shape</td>
#       <td id="T_4710f_row1_col1" class="data row1 col1" >(440, 8)</td>
#     </tr>
#     <tr>
#       <th id="T_4710f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_4710f_row2_col0" class="data row2 col0" >Transformed data shape</td>
#       <td id="T_4710f_row2_col1" class="data row2 col1" >(440, 8)</td>
#     </tr>
#     <tr>
#       <th id="T_4710f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_4710f_row3_col0" class="data row3 col0" >Numeric features</td>
#       <td id="T_4710f_row3_col1" class="data row3 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_4710f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_4710f_row4_col0" class="data row4 col0" >Preprocess</td>
#       <td id="T_4710f_row4_col1" class="data row4 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_4710f_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_4710f_row5_col0" class="data row5 col0" >Imputation type</td>
#       <td id="T_4710f_row5_col1" class="data row5 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_4710f_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_4710f_row6_col0" class="data row6 col0" >Numeric imputation</td>
#       <td id="T_4710f_row6_col1" class="data row6 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_4710f_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_4710f_row7_col0" class="data row7 col0" >Categorical imputation</td>
#       <td id="T_4710f_row7_col1" class="data row7 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_4710f_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_4710f_row8_col0" class="data row8 col0" >CPU Jobs</td>
#       <td id="T_4710f_row8_col1" class="data row8 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_4710f_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_4710f_row9_col0" class="data row9 col0" >Use GPU</td>
#       <td id="T_4710f_row9_col1" class="data row9 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_4710f_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_4710f_row10_col0" class="data row10 col0" >Log Experiment</td>
#       <td id="T_4710f_row10_col1" class="data row10 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_4710f_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_4710f_row11_col0" class="data row11 col0" >Experiment Name</td>
#       <td id="T_4710f_row11_col1" class="data row11 col1" >cluster-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_4710f_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_4710f_row12_col0" class="data row12 col0" >USI</td>
#       <td id="T_4710f_row12_col1" class="data row12 col1" >813b</td>
#     </tr>
#   </tbody>
# </table>

# %%
# KMeanClusteringModel3 = create_model('kmeans', num_clusters=3)

# %%
# KMeanClusteringModel4 = create_model('kmeans', num_clusters=4)

# %%
# KMeanClusteringModel5 = create_model('kmeans', num_clusters=5)

# %%
# kMeanPrediction3 = assign_model(KMeanClusteringModel3)
# kMeanPrediction3

# %%
# kMeanPrediction4 = assign_model(KMeanClusteringModel4)
# kMeanPrediction4

# %%
# kMeanPrediction5 = assign_model(KMeanClusteringModel5)
# kMeanPrediction5

# %% [markdown]
# # **FOR K-MEANS CLUSTERING**

# %% [markdown]
# No Data Pre-processing

# %%
setup(data = data, verbose=False)

print("For Cluster = 3")
x3 = create_model('kmeans', num_clusters = 3)

print("For Cluster = 4")
x4 = create_model('kmeans', num_clusters = 4)

print("For Cluster = 5")
x5 = create_model('kmeans', num_clusters = 5)

x = create_model('kmeans')
plot_model(x, plot = 'elbow')
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_94814" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_94814_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_94814_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_94814_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_94814_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_94814_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_94814_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_94814_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_94814_row0_col0" class="data row0 col0" >0.4770</td>
#       <td id="T_94814_row0_col1" class="data row0 col1" >210.1456</td>
#       <td id="T_94814_row0_col2" class="data row0 col2" >0.8905</td>
#       <td id="T_94814_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_94814_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_94814_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 4
# <style type="text/css">
# </style>
# <table id="T_3cefa" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3cefa_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_3cefa_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_3cefa_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_3cefa_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_3cefa_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_3cefa_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3cefa_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3cefa_row0_col0" class="data row0 col0" >0.4144</td>
#       <td id="T_3cefa_row0_col1" class="data row0 col1" >206.4566</td>
#       <td id="T_3cefa_row0_col2" class="data row0 col2" >0.8648</td>
#       <td id="T_3cefa_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_3cefa_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_3cefa_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 5
# <style type="text/css">
# </style>
# <table id="T_c136a" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c136a_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_c136a_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_c136a_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_c136a_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_c136a_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_c136a_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c136a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c136a_row0_col0" class="data row0 col0" >0.3690</td>
#       <td id="T_c136a_row0_col1" class="data row0 col1" >213.9071</td>
#       <td id="T_c136a_row0_col2" class="data row0 col2" >0.8906</td>
#       <td id="T_c136a_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_c136a_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_c136a_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_63d32" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_63d32_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_63d32_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_63d32_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_63d32_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_63d32_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_63d32_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_63d32_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_63d32_row0_col0" class="data row0 col0" >0.4144</td>
#       <td id="T_63d32_row0_col1" class="data row0 col1" >206.4566</td>
#       <td id="T_63d32_row0_col2" class="data row0 col2" >0.8648</td>
#       <td id="T_63d32_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_63d32_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_63d32_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]

# %% [markdown]
# With Normalization

# %%
setup(data = data, normalize = True, normalize_method = 'zscore', verbose=False)

print("For Cluster = 3")
x3 = create_model('kmeans', num_clusters = 3)

print("For Cluster = 4")
x4 = create_model('kmeans', num_clusters = 4)

print("For Cluster = 5")
x5 = create_model('kmeans', num_clusters = 5)


x = create_model('kmeans')
plot_model(x, plot = 'elbow')
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_69bb7" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_69bb7_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_69bb7_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_69bb7_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_69bb7_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_69bb7_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_69bb7_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_69bb7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_69bb7_row0_col0" class="data row0 col0" >0.3568</td>
#       <td id="T_69bb7_row0_col1" class="data row0 col1" >139.3494</td>
#       <td id="T_69bb7_row0_col2" class="data row0 col2" >1.1736</td>
#       <td id="T_69bb7_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_69bb7_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_69bb7_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 4
# <style type="text/css">
# </style>
# <table id="T_8a2c8" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8a2c8_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_8a2c8_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_8a2c8_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_8a2c8_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_8a2c8_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_8a2c8_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8a2c8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8a2c8_row0_col0" class="data row0 col0" >0.3482</td>
#       <td id="T_8a2c8_row0_col1" class="data row0 col1" >130.9179</td>
#       <td id="T_8a2c8_row0_col2" class="data row0 col2" >1.2359</td>
#       <td id="T_8a2c8_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_8a2c8_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_8a2c8_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 5
# <style type="text/css">
# </style>
# <table id="T_c9c44" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c9c44_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_c9c44_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_c9c44_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_c9c44_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_c9c44_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_c9c44_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c9c44_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c9c44_row0_col0" class="data row0 col0" >0.3513</td>
#       <td id="T_c9c44_row0_col1" class="data row0 col1" >136.3530</td>
#       <td id="T_c9c44_row0_col2" class="data row0 col2" >0.9769</td>
#       <td id="T_c9c44_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_c9c44_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_c9c44_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_8f950" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8f950_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_8f950_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_8f950_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_8f950_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_8f950_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_8f950_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8f950_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8f950_row0_col0" class="data row0 col0" >0.3482</td>
#       <td id="T_8f950_row0_col1" class="data row0 col1" >130.9179</td>
#       <td id="T_8f950_row0_col2" class="data row0 col2" >1.2359</td>
#       <td id="T_8f950_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_8f950_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_8f950_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]

# %% [markdown]
# With Transformation

# %%
setup(data = data, transformation = True, transformation_method = 'yeo-johnson', verbose=False)

print("For Cluster = 3")
x3 = create_model('kmeans', num_clusters = 3)

print("For Cluster = 4")
x4 = create_model('kmeans', num_clusters = 4)

print("For Cluster = 5")
x5 = create_model('kmeans', num_clusters = 5)

x = create_model('kmeans')
plot_model(x, plot = 'elbow')
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_bacd0" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bacd0_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_bacd0_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_bacd0_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_bacd0_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_bacd0_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_bacd0_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bacd0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_bacd0_row0_col0" class="data row0 col0" >0.8554</td>
#       <td id="T_bacd0_row0_col1" class="data row0 col1" >13039.7633</td>
#       <td id="T_bacd0_row0_col2" class="data row0 col2" >0.3389</td>
#       <td id="T_bacd0_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_bacd0_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_bacd0_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 4
# <style type="text/css">
# </style>
# <table id="T_f573f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f573f_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_f573f_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_f573f_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_f573f_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_f573f_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_f573f_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f573f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f573f_row0_col0" class="data row0 col0" >0.5181</td>
#       <td id="T_f573f_row0_col1" class="data row0 col1" >15162.6315</td>
#       <td id="T_f573f_row0_col2" class="data row0 col2" >0.6203</td>
#       <td id="T_f573f_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_f573f_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_f573f_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 5
# <style type="text/css">
# </style>
# <table id="T_65da1" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_65da1_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_65da1_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_65da1_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_65da1_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_65da1_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_65da1_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_65da1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_65da1_row0_col0" class="data row0 col0" >0.4626</td>
#       <td id="T_65da1_row0_col1" class="data row0 col1" >14223.7871</td>
#       <td id="T_65da1_row0_col2" class="data row0 col2" >0.6958</td>
#       <td id="T_65da1_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_65da1_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_65da1_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_b60e3" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b60e3_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_b60e3_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_b60e3_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_b60e3_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_b60e3_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_b60e3_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b60e3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b60e3_row0_col0" class="data row0 col0" >0.5181</td>
#       <td id="T_b60e3_row0_col1" class="data row0 col1" >15162.6315</td>
#       <td id="T_b60e3_row0_col2" class="data row0 col2" >0.6203</td>
#       <td id="T_b60e3_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_b60e3_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_b60e3_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]

# %% [markdown]
# With PCA

# %%
setup(data = data, pca = True, pca_method = 'linear', verbose=False)

print("For Cluster = 3")
x3 = create_model('kmeans', num_clusters = 3)

print("For Cluster = 4")
x4 = create_model('kmeans', num_clusters = 4)

print("For Cluster = 5")
x5 = create_model('kmeans', num_clusters = 5)

x = create_model('kmeans')
plot_model(x, plot = 'elbow')
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_1ed53" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1ed53_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_1ed53_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_1ed53_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_1ed53_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_1ed53_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_1ed53_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1ed53_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1ed53_row0_col0" class="data row0 col0" >0.4770</td>
#       <td id="T_1ed53_row0_col1" class="data row0 col1" >210.1456</td>
#       <td id="T_1ed53_row0_col2" class="data row0 col2" >0.8905</td>
#       <td id="T_1ed53_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_1ed53_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_1ed53_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 4
# <style type="text/css">
# </style>
# <table id="T_1461d" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1461d_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_1461d_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_1461d_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_1461d_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_1461d_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_1461d_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1461d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1461d_row0_col0" class="data row0 col0" >0.3866</td>
#       <td id="T_1461d_row0_col1" class="data row0 col1" >207.8197</td>
#       <td id="T_1461d_row0_col2" class="data row0 col2" >0.9543</td>
#       <td id="T_1461d_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_1461d_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_1461d_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 5
# <style type="text/css">
# </style>
# <table id="T_b0335" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b0335_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_b0335_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_b0335_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_b0335_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_b0335_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_b0335_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b0335_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b0335_row0_col0" class="data row0 col0" >0.3696</td>
#       <td id="T_b0335_row0_col1" class="data row0 col1" >213.1525</td>
#       <td id="T_b0335_row0_col2" class="data row0 col2" >0.9416</td>
#       <td id="T_b0335_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_b0335_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_b0335_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_640ba" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_640ba_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_640ba_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_640ba_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_640ba_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_640ba_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_640ba_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_640ba_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_640ba_row0_col0" class="data row0 col0" >0.3866</td>
#       <td id="T_640ba_row0_col1" class="data row0 col1" >207.8197</td>
#       <td id="T_640ba_row0_col2" class="data row0 col2" >0.9543</td>
#       <td id="T_640ba_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_640ba_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_640ba_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]

# %% [markdown]
# With Transformation + Normalization

# %%
setup(data = data, transformation = True, normalize = True,
      normalize_method = 'zscore', transformation_method = 'yeo-johnson', verbose=False)

print("For Cluster = 3")
x3 = create_model('kmeans', num_clusters = 3)

print("For Cluster = 4")
x4 = create_model('kmeans', num_clusters = 4)

print("For Cluster = 5")
x5 = create_model('kmeans', num_clusters = 5)

x = create_model('kmeans')
plot_model(x, plot = 'elbow')
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_194fd" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_194fd_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_194fd_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_194fd_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_194fd_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_194fd_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_194fd_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_194fd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_194fd_row0_col0" class="data row0 col0" >0.2228</td>
#       <td id="T_194fd_row0_col1" class="data row0 col1" >153.5484</td>
#       <td id="T_194fd_row0_col2" class="data row0 col2" >1.6406</td>
#       <td id="T_194fd_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_194fd_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_194fd_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 4
# <style type="text/css">
# </style>
# <table id="T_d9b42" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d9b42_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_d9b42_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_d9b42_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_d9b42_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_d9b42_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_d9b42_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d9b42_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d9b42_row0_col0" class="data row0 col0" >0.2472</td>
#       <td id="T_d9b42_row0_col1" class="data row0 col1" >136.3349</td>
#       <td id="T_d9b42_row0_col2" class="data row0 col2" >1.4208</td>
#       <td id="T_d9b42_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_d9b42_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_d9b42_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 5
# <style type="text/css">
# </style>
# <table id="T_9fcea" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9fcea_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_9fcea_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_9fcea_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_9fcea_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_9fcea_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_9fcea_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9fcea_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9fcea_row0_col0" class="data row0 col0" >0.2150</td>
#       <td id="T_9fcea_row0_col1" class="data row0 col1" >120.5387</td>
#       <td id="T_9fcea_row0_col2" class="data row0 col2" >1.6119</td>
#       <td id="T_9fcea_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_9fcea_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_9fcea_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_94cfb" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_94cfb_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_94cfb_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_94cfb_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_94cfb_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_94cfb_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_94cfb_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_94cfb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_94cfb_row0_col0" class="data row0 col0" >0.2472</td>
#       <td id="T_94cfb_row0_col1" class="data row0 col1" >136.3349</td>
#       <td id="T_94cfb_row0_col2" class="data row0 col2" >1.4208</td>
#       <td id="T_94cfb_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_94cfb_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_94cfb_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]

# %% [markdown]
# With Transformation + Normalization + PCA

# %%
setup(data = data, transformation = True, normalize = True, pca = True,
      normalize_method = 'zscore',
      transformation_method = 'yeo-johnson',
      pca_method = 'linear', verbose=False)

print("For Cluster = 3")
x3 = create_model('kmeans', num_clusters = 3)

print("For Cluster = 4")
x4 = create_model('kmeans', num_clusters = 4)

print("For Cluster = 5")
x5 = create_model('kmeans', num_clusters = 5)

x = create_model('kmeans')
plot_model(x, plot = 'elbow')
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_644dd" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_644dd_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_644dd_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_644dd_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_644dd_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_644dd_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_644dd_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_644dd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_644dd_row0_col0" class="data row0 col0" >0.2228</td>
#       <td id="T_644dd_row0_col1" class="data row0 col1" >153.5484</td>
#       <td id="T_644dd_row0_col2" class="data row0 col2" >1.6406</td>
#       <td id="T_644dd_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_644dd_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_644dd_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 4
# <style type="text/css">
# </style>
# <table id="T_a25cb" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a25cb_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_a25cb_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_a25cb_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_a25cb_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_a25cb_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_a25cb_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a25cb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a25cb_row0_col0" class="data row0 col0" >0.2473</td>
#       <td id="T_a25cb_row0_col1" class="data row0 col1" >136.3422</td>
#       <td id="T_a25cb_row0_col2" class="data row0 col2" >1.4213</td>
#       <td id="T_a25cb_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_a25cb_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_a25cb_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 5
# <style type="text/css">
# </style>
# <table id="T_e351a" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e351a_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_e351a_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_e351a_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_e351a_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_e351a_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_e351a_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e351a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e351a_row0_col0" class="data row0 col0" >0.2135</td>
#       <td id="T_e351a_row0_col1" class="data row0 col1" >120.5274</td>
#       <td id="T_e351a_row0_col2" class="data row0 col2" >1.6109</td>
#       <td id="T_e351a_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_e351a_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_e351a_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_284bf" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_284bf_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_284bf_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_284bf_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_284bf_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_284bf_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_284bf_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_284bf_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_284bf_row0_col0" class="data row0 col0" >0.2473</td>
#       <td id="T_284bf_row0_col1" class="data row0 col1" >136.3422</td>
#       <td id="T_284bf_row0_col2" class="data row0 col2" >1.4213</td>
#       <td id="T_284bf_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_284bf_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_284bf_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]

# %% [markdown]
# # **FOR HIERARCHICAL CLUSTERING**

# %% [markdown]
# No Data Pre-processing

# %%
setup(data = data, verbose=False)

print("For Cluster = 3")
x3 = create_model('hclust', num_clusters = 3)

print("For Cluster = 4")
x4 = create_model('hclust', num_clusters = 4)

print("For Cluster = 5")
x5 = create_model('hclust', num_clusters = 5)

x = create_model('hclust')
plot_model(x, plot = 'elbow')
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_836b8" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_836b8_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_836b8_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_836b8_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_836b8_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_836b8_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_836b8_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_836b8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_836b8_row0_col0" class="data row0 col0" >0.3750</td>
#       <td id="T_836b8_row0_col1" class="data row0 col1" >183.3597</td>
#       <td id="T_836b8_row0_col2" class="data row0 col2" >0.9783</td>
#       <td id="T_836b8_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_836b8_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_836b8_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 4
# <style type="text/css">
# </style>
# <table id="T_9d05c" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9d05c_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_9d05c_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_9d05c_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_9d05c_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_9d05c_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_9d05c_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9d05c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9d05c_row0_col0" class="data row0 col0" >0.3483</td>
#       <td id="T_9d05c_row0_col1" class="data row0 col1" >185.2559</td>
#       <td id="T_9d05c_row0_col2" class="data row0 col2" >0.9701</td>
#       <td id="T_9d05c_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_9d05c_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_9d05c_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 5
# <style type="text/css">
# </style>
# <table id="T_8852e" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8852e_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_8852e_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_8852e_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_8852e_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_8852e_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_8852e_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8852e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8852e_row0_col0" class="data row0 col0" >0.3522</td>
#       <td id="T_8852e_row0_col1" class="data row0 col1" >196.9540</td>
#       <td id="T_8852e_row0_col2" class="data row0 col2" >0.9106</td>
#       <td id="T_8852e_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_8852e_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_8852e_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_bdb26" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bdb26_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_bdb26_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_bdb26_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_bdb26_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_bdb26_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_bdb26_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bdb26_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_bdb26_row0_col0" class="data row0 col0" >0.3483</td>
#       <td id="T_bdb26_row0_col1" class="data row0 col1" >185.2559</td>
#       <td id="T_bdb26_row0_col2" class="data row0 col2" >0.9701</td>
#       <td id="T_bdb26_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_bdb26_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_bdb26_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]

# %% [markdown]
# With Normalization

# %%
setup(data = data, normalize = True, normalize_method = 'zscore', verbose=False)

print("For Cluster = 3")
x3 = create_model('hclust', num_clusters = 3)

print("For Cluster = 4")
x4 = create_model('hclust', num_clusters = 4)

print("For Cluster = 5")
x5 = create_model('hclust', num_clusters = 5)

x = create_model('hclust')
plot_model(x, plot = 'elbow')
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_98f8f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_98f8f_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_98f8f_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_98f8f_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_98f8f_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_98f8f_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_98f8f_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_98f8f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_98f8f_row0_col0" class="data row0 col0" >0.3600</td>
#       <td id="T_98f8f_row0_col1" class="data row0 col1" >126.2475</td>
#       <td id="T_98f8f_row0_col2" class="data row0 col2" >1.1551</td>
#       <td id="T_98f8f_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_98f8f_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_98f8f_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 4
# <style type="text/css">
# </style>
# <table id="T_984db" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_984db_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_984db_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_984db_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_984db_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_984db_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_984db_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_984db_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_984db_row0_col0" class="data row0 col0" >0.3623</td>
#       <td id="T_984db_row0_col1" class="data row0 col1" >120.7561</td>
#       <td id="T_984db_row0_col2" class="data row0 col2" >0.8255</td>
#       <td id="T_984db_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_984db_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_984db_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 5
# <style type="text/css">
# </style>
# <table id="T_b2926" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b2926_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_b2926_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_b2926_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_b2926_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_b2926_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_b2926_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b2926_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b2926_row0_col0" class="data row0 col0" >0.3178</td>
#       <td id="T_b2926_row0_col1" class="data row0 col1" >123.5061</td>
#       <td id="T_b2926_row0_col2" class="data row0 col2" >0.8960</td>
#       <td id="T_b2926_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_b2926_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_b2926_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_facd5" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_facd5_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_facd5_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_facd5_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_facd5_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_facd5_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_facd5_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_facd5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_facd5_row0_col0" class="data row0 col0" >0.3623</td>
#       <td id="T_facd5_row0_col1" class="data row0 col1" >120.7561</td>
#       <td id="T_facd5_row0_col2" class="data row0 col2" >0.8255</td>
#       <td id="T_facd5_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_facd5_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_facd5_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]

# %% [markdown]
# With Transformation

# %%
setup(data = data, transformation = True, transformation_method = 'yeo-johnson', verbose=False)

print("For Cluster = 3")
x3 = create_model('hclust', num_clusters = 3)

print("For Cluster = 4")
x4 = create_model('hclust', num_clusters = 4)

print("For Cluster = 5")
x5 = create_model('hclust', num_clusters = 5)

x = create_model('hclust')
plot_model(x, plot = 'elbow')
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_3c25c" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3c25c_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_3c25c_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_3c25c_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_3c25c_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_3c25c_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_3c25c_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3c25c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3c25c_row0_col0" class="data row0 col0" >0.8554</td>
#       <td id="T_3c25c_row0_col1" class="data row0 col1" >13039.7633</td>
#       <td id="T_3c25c_row0_col2" class="data row0 col2" >0.3389</td>
#       <td id="T_3c25c_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_3c25c_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_3c25c_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 4
# <style type="text/css">
# </style>
# <table id="T_93076" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_93076_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_93076_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_93076_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_93076_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_93076_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_93076_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_93076_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_93076_row0_col0" class="data row0 col0" >0.5109</td>
#       <td id="T_93076_row0_col1" class="data row0 col1" >14291.9587</td>
#       <td id="T_93076_row0_col2" class="data row0 col2" >0.6054</td>
#       <td id="T_93076_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_93076_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_93076_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 5
# <style type="text/css">
# </style>
# <table id="T_2632f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2632f_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_2632f_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_2632f_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_2632f_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_2632f_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_2632f_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2632f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2632f_row0_col0" class="data row0 col0" >0.4530</td>
#       <td id="T_2632f_row0_col1" class="data row0 col1" >14101.6445</td>
#       <td id="T_2632f_row0_col2" class="data row0 col2" >0.7125</td>
#       <td id="T_2632f_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_2632f_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_2632f_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_ce7b8" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ce7b8_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_ce7b8_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_ce7b8_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_ce7b8_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_ce7b8_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_ce7b8_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ce7b8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ce7b8_row0_col0" class="data row0 col0" >0.5109</td>
#       <td id="T_ce7b8_row0_col1" class="data row0 col1" >14291.9587</td>
#       <td id="T_ce7b8_row0_col2" class="data row0 col2" >0.6054</td>
#       <td id="T_ce7b8_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_ce7b8_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_ce7b8_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]

# %% [markdown]
# With PCA

# %%
setup(data = data, pca = True, pca_method = 'linear', verbose=False)

print("For Cluster = 3")
x3 = create_model('hclust', num_clusters = 3)

print("For Cluster = 4")
x4 = create_model('hclust', num_clusters = 4)

print("For Cluster = 5")
x5 = create_model('hclust', num_clusters = 5)

x = create_model('hclust')
plot_model(x, plot = 'elbow')
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_e33b2" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e33b2_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_e33b2_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_e33b2_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_e33b2_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_e33b2_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_e33b2_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e33b2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e33b2_row0_col0" class="data row0 col0" >0.3750</td>
#       <td id="T_e33b2_row0_col1" class="data row0 col1" >183.3597</td>
#       <td id="T_e33b2_row0_col2" class="data row0 col2" >0.9783</td>
#       <td id="T_e33b2_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_e33b2_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_e33b2_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 4
# <style type="text/css">
# </style>
# <table id="T_cb49f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cb49f_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_cb49f_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_cb49f_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_cb49f_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_cb49f_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_cb49f_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cb49f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cb49f_row0_col0" class="data row0 col0" >0.3483</td>
#       <td id="T_cb49f_row0_col1" class="data row0 col1" >185.2559</td>
#       <td id="T_cb49f_row0_col2" class="data row0 col2" >0.9701</td>
#       <td id="T_cb49f_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_cb49f_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_cb49f_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 5
# <style type="text/css">
# </style>
# <table id="T_90ad0" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_90ad0_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_90ad0_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_90ad0_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_90ad0_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_90ad0_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_90ad0_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_90ad0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_90ad0_row0_col0" class="data row0 col0" >0.3522</td>
#       <td id="T_90ad0_row0_col1" class="data row0 col1" >196.9540</td>
#       <td id="T_90ad0_row0_col2" class="data row0 col2" >0.9106</td>
#       <td id="T_90ad0_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_90ad0_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_90ad0_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_9caac" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9caac_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_9caac_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_9caac_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_9caac_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_9caac_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_9caac_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9caac_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9caac_row0_col0" class="data row0 col0" >0.3483</td>
#       <td id="T_9caac_row0_col1" class="data row0 col1" >185.2559</td>
#       <td id="T_9caac_row0_col2" class="data row0 col2" >0.9701</td>
#       <td id="T_9caac_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_9caac_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_9caac_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]

# %% [markdown]
# With Transformation + Normalization

# %%
setup(data = data, transformation = True, normalize = True,
      normalize_method = 'zscore', transformation_method = 'yeo-johnson', verbose=False)

print("For Cluster = 3")
x3 = create_model('hclust', num_clusters = 3)

print("For Cluster = 4")
x4 = create_model('hclust', num_clusters = 4)

print("For Cluster = 5")
x5 = create_model('hclust', num_clusters = 5)

x = create_model('hclust')
plot_model(x, plot = 'elbow')
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_6abdf" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6abdf_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_6abdf_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_6abdf_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_6abdf_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_6abdf_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_6abdf_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6abdf_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6abdf_row0_col0" class="data row0 col0" >0.2288</td>
#       <td id="T_6abdf_row0_col1" class="data row0 col1" >138.5574</td>
#       <td id="T_6abdf_row0_col2" class="data row0 col2" >1.5189</td>
#       <td id="T_6abdf_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_6abdf_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_6abdf_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 4
# <style type="text/css">
# </style>
# <table id="T_4e391" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4e391_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_4e391_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_4e391_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_4e391_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_4e391_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_4e391_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4e391_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4e391_row0_col0" class="data row0 col0" >0.2425</td>
#       <td id="T_4e391_row0_col1" class="data row0 col1" >127.8460</td>
#       <td id="T_4e391_row0_col2" class="data row0 col2" >1.4576</td>
#       <td id="T_4e391_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_4e391_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_4e391_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 5
# <style type="text/css">
# </style>
# <table id="T_f3a67" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f3a67_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_f3a67_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_f3a67_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_f3a67_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_f3a67_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_f3a67_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f3a67_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f3a67_row0_col0" class="data row0 col0" >0.2073</td>
#       <td id="T_f3a67_row0_col1" class="data row0 col1" >112.2108</td>
#       <td id="T_f3a67_row0_col2" class="data row0 col2" >1.4930</td>
#       <td id="T_f3a67_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_f3a67_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_f3a67_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_b28a6" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b28a6_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_b28a6_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_b28a6_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_b28a6_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_b28a6_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_b28a6_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b28a6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b28a6_row0_col0" class="data row0 col0" >0.2425</td>
#       <td id="T_b28a6_row0_col1" class="data row0 col1" >127.8460</td>
#       <td id="T_b28a6_row0_col2" class="data row0 col2" >1.4576</td>
#       <td id="T_b28a6_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_b28a6_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_b28a6_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]

# %% [markdown]
# With Transformation + Normalization + PCA

# %%
setup(data = data, transformation = True, normalize = True, pca = True,
      normalize_method = 'zscore',
      transformation_method = 'yeo-johnson',
      pca_method = 'linear', verbose=False)

print("For Cluster = 3")
x3 = create_model('hclust', num_clusters = 3)

print("For Cluster = 4")
x4 = create_model('hclust', num_clusters = 4)

print("For Cluster = 5")
x5 = create_model('hclust', num_clusters = 5)

x = create_model('hclust')
plot_model(x, plot = 'elbow')
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_0d83e" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0d83e_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_0d83e_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_0d83e_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_0d83e_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_0d83e_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_0d83e_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0d83e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0d83e_row0_col0" class="data row0 col0" >0.2288</td>
#       <td id="T_0d83e_row0_col1" class="data row0 col1" >138.5574</td>
#       <td id="T_0d83e_row0_col2" class="data row0 col2" >1.5189</td>
#       <td id="T_0d83e_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_0d83e_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_0d83e_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 4
# <style type="text/css">
# </style>
# <table id="T_cbd3a" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cbd3a_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_cbd3a_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_cbd3a_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_cbd3a_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_cbd3a_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_cbd3a_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cbd3a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cbd3a_row0_col0" class="data row0 col0" >0.2425</td>
#       <td id="T_cbd3a_row0_col1" class="data row0 col1" >127.8460</td>
#       <td id="T_cbd3a_row0_col2" class="data row0 col2" >1.4576</td>
#       <td id="T_cbd3a_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_cbd3a_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_cbd3a_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 5
# <style type="text/css">
# </style>
# <table id="T_37aa8" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_37aa8_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_37aa8_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_37aa8_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_37aa8_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_37aa8_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_37aa8_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_37aa8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_37aa8_row0_col0" class="data row0 col0" >0.2073</td>
#       <td id="T_37aa8_row0_col1" class="data row0 col1" >112.2108</td>
#       <td id="T_37aa8_row0_col2" class="data row0 col2" >1.4930</td>
#       <td id="T_37aa8_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_37aa8_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_37aa8_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_a6946" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a6946_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_a6946_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_a6946_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_a6946_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_a6946_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_a6946_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a6946_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a6946_row0_col0" class="data row0 col0" >0.2425</td>
#       <td id="T_a6946_row0_col1" class="data row0 col1" >127.8460</td>
#       <td id="T_a6946_row0_col2" class="data row0 col2" >1.4576</td>
#       <td id="T_a6946_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_a6946_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_a6946_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]

# %% [markdown]
# # **FOR K-MEAN SHIFT CLUSTERING**

# %% [markdown]
# No Data Pre-processing

# %%
setup(data = data, verbose=False)

print("For Cluster = 3")
x3 = create_model('meanshift', num_clusters = 3)

print("For Cluster = 4")
x4 = create_model('meanshift', num_clusters = 4)

print("For Cluster = 5")
x5 = create_model('meanshift', num_clusters = 5)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_95cd6" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_95cd6_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_95cd6_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_95cd6_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_95cd6_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_95cd6_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_95cd6_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_95cd6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_95cd6_row0_col0" class="data row0 col0" >0.3644</td>
#       <td id="T_95cd6_row0_col1" class="data row0 col1" >54.7541</td>
#       <td id="T_95cd6_row0_col2" class="data row0 col2" >0.5765</td>
#       <td id="T_95cd6_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_95cd6_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_95cd6_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 4
# <style type="text/css">
# </style>
# <table id="T_9a8eb" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9a8eb_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_9a8eb_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_9a8eb_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_9a8eb_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_9a8eb_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_9a8eb_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9a8eb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9a8eb_row0_col0" class="data row0 col0" >0.3644</td>
#       <td id="T_9a8eb_row0_col1" class="data row0 col1" >54.7541</td>
#       <td id="T_9a8eb_row0_col2" class="data row0 col2" >0.5765</td>
#       <td id="T_9a8eb_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_9a8eb_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_9a8eb_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 5
# <style type="text/css">
# </style>
# <table id="T_07de6" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_07de6_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_07de6_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_07de6_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_07de6_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_07de6_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_07de6_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_07de6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_07de6_row0_col0" class="data row0 col0" >0.3644</td>
#       <td id="T_07de6_row0_col1" class="data row0 col1" >54.7541</td>
#       <td id="T_07de6_row0_col2" class="data row0 col2" >0.5765</td>
#       <td id="T_07de6_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_07de6_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_07de6_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]

# %% [markdown]
# With Normalization

# %%
setup(data = data, normalize = True, normalize_method = 'zscore', verbose=False)

print("For Cluster = 3")
x3 = create_model('meanshift', num_clusters = 3)

print("For Cluster = 4")
x4 = create_model('meanshift', num_clusters = 4)

print("For Cluster = 5")
x5 = create_model('meanshift', num_clusters = 5)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_0998d" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0998d_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_0998d_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_0998d_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_0998d_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_0998d_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_0998d_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0998d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0998d_row0_col0" class="data row0 col0" >0.4054</td>
#       <td id="T_0998d_row0_col1" class="data row0 col1" >30.8599</td>
#       <td id="T_0998d_row0_col2" class="data row0 col2" >0.4229</td>
#       <td id="T_0998d_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_0998d_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_0998d_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 4
# <style type="text/css">
# </style>
# <table id="T_d4aa1" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d4aa1_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_d4aa1_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_d4aa1_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_d4aa1_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_d4aa1_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_d4aa1_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d4aa1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d4aa1_row0_col0" class="data row0 col0" >0.4054</td>
#       <td id="T_d4aa1_row0_col1" class="data row0 col1" >30.8599</td>
#       <td id="T_d4aa1_row0_col2" class="data row0 col2" >0.4229</td>
#       <td id="T_d4aa1_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_d4aa1_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_d4aa1_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 5
# <style type="text/css">
# </style>
# <table id="T_fc26f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fc26f_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_fc26f_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_fc26f_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_fc26f_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_fc26f_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_fc26f_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fc26f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fc26f_row0_col0" class="data row0 col0" >0.4054</td>
#       <td id="T_fc26f_row0_col1" class="data row0 col1" >30.8599</td>
#       <td id="T_fc26f_row0_col2" class="data row0 col2" >0.4229</td>
#       <td id="T_fc26f_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_fc26f_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_fc26f_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]

# %% [markdown]
# With Transformation

# %%
setup(data = data, transformation = True, transformation_method = 'yeo-johnson', verbose=False)

print("For Cluster = 3")
x3 = create_model('meanshift', num_clusters = 3)

print("For Cluster = 4")
x4 = create_model('meanshift', num_clusters = 4)

print("For Cluster = 5")
x5 = create_model('meanshift', num_clusters = 5)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_44ec1" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_44ec1_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_44ec1_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_44ec1_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_44ec1_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_44ec1_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_44ec1_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_44ec1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_44ec1_row0_col0" class="data row0 col0" >0.9076</td>
#       <td id="T_44ec1_row0_col1" class="data row0 col1" >14114.2429</td>
#       <td id="T_44ec1_row0_col2" class="data row0 col2" >0.1625</td>
#       <td id="T_44ec1_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_44ec1_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_44ec1_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 4
# <style type="text/css">
# </style>
# <table id="T_664cc" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_664cc_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_664cc_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_664cc_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_664cc_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_664cc_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_664cc_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_664cc_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_664cc_row0_col0" class="data row0 col0" >0.9076</td>
#       <td id="T_664cc_row0_col1" class="data row0 col1" >14114.2429</td>
#       <td id="T_664cc_row0_col2" class="data row0 col2" >0.1625</td>
#       <td id="T_664cc_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_664cc_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_664cc_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 5
# <style type="text/css">
# </style>
# <table id="T_379ef" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_379ef_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_379ef_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_379ef_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_379ef_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_379ef_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_379ef_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_379ef_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_379ef_row0_col0" class="data row0 col0" >0.9076</td>
#       <td id="T_379ef_row0_col1" class="data row0 col1" >14114.2429</td>
#       <td id="T_379ef_row0_col2" class="data row0 col2" >0.1625</td>
#       <td id="T_379ef_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_379ef_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_379ef_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]

# %% [markdown]
# With PCA

# %%
setup(data = data, pca = True, pca_method = 'linear', verbose=False)

print("For Cluster = 3")
x3 = create_model('meanshift', num_clusters = 3)

print("For Cluster = 4")
x4 = create_model('meanshift', num_clusters = 4)

print("For Cluster = 5")
x5 = create_model('meanshift', num_clusters = 5)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_1a971" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1a971_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_1a971_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_1a971_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_1a971_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_1a971_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_1a971_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1a971_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1a971_row0_col0" class="data row0 col0" >0.3644</td>
#       <td id="T_1a971_row0_col1" class="data row0 col1" >54.7541</td>
#       <td id="T_1a971_row0_col2" class="data row0 col2" >0.5765</td>
#       <td id="T_1a971_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_1a971_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_1a971_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 4
# <style type="text/css">
# </style>
# <table id="T_84254" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_84254_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_84254_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_84254_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_84254_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_84254_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_84254_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_84254_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_84254_row0_col0" class="data row0 col0" >0.3644</td>
#       <td id="T_84254_row0_col1" class="data row0 col1" >54.7541</td>
#       <td id="T_84254_row0_col2" class="data row0 col2" >0.5765</td>
#       <td id="T_84254_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_84254_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_84254_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 5
# <style type="text/css">
# </style>
# <table id="T_dfe6f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dfe6f_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_dfe6f_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_dfe6f_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_dfe6f_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_dfe6f_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_dfe6f_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dfe6f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_dfe6f_row0_col0" class="data row0 col0" >0.3644</td>
#       <td id="T_dfe6f_row0_col1" class="data row0 col1" >54.7541</td>
#       <td id="T_dfe6f_row0_col2" class="data row0 col2" >0.5765</td>
#       <td id="T_dfe6f_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_dfe6f_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_dfe6f_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]

# %% [markdown]
# With Transformation + Normalization

# %%
setup(data = data, transformation = True, normalize = True,
      normalize_method = 'zscore', transformation_method = 'yeo-johnson', verbose=False)

print("For Cluster = 3")
x3 = create_model('meanshift', num_clusters = 3)

print("For Cluster = 4")
x4 = create_model('meanshift', num_clusters = 4)

print("For Cluster = 5")
x5 = create_model('meanshift', num_clusters = 5)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_e342d" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e342d_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_e342d_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_e342d_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_e342d_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_e342d_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_e342d_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e342d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e342d_row0_col0" class="data row0 col0" >0.3461</td>
#       <td id="T_e342d_row0_col1" class="data row0 col1" >17.4754</td>
#       <td id="T_e342d_row0_col2" class="data row0 col2" >1.0571</td>
#       <td id="T_e342d_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_e342d_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_e342d_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 4
# <style type="text/css">
# </style>
# <table id="T_9f967" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9f967_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_9f967_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_9f967_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_9f967_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_9f967_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_9f967_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9f967_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9f967_row0_col0" class="data row0 col0" >0.3461</td>
#       <td id="T_9f967_row0_col1" class="data row0 col1" >17.4754</td>
#       <td id="T_9f967_row0_col2" class="data row0 col2" >1.0571</td>
#       <td id="T_9f967_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_9f967_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_9f967_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 5
# <style type="text/css">
# </style>
# <table id="T_e2571" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e2571_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_e2571_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_e2571_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_e2571_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_e2571_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_e2571_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e2571_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e2571_row0_col0" class="data row0 col0" >0.3461</td>
#       <td id="T_e2571_row0_col1" class="data row0 col1" >17.4754</td>
#       <td id="T_e2571_row0_col2" class="data row0 col2" >1.0571</td>
#       <td id="T_e2571_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_e2571_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_e2571_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]

# %% [markdown]
# With Transformation + Normalization + PCA

# %%
setup(data = data, transformation = True, normalize = True, pca = True,
      normalize_method = 'zscore',
      transformation_method = 'yeo-johnson',
      pca_method = 'linear', verbose=False)

print("For Cluster = 3")
x3 = create_model('meanshift', num_clusters = 3)

print("For Cluster = 4")
x4 = create_model('meanshift', num_clusters = 4)

print("For Cluster = 5")
x5 = create_model('meanshift', num_clusters = 5)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_ac8be" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ac8be_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_ac8be_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_ac8be_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_ac8be_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_ac8be_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_ac8be_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ac8be_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ac8be_row0_col0" class="data row0 col0" >0.3461</td>
#       <td id="T_ac8be_row0_col1" class="data row0 col1" >17.4754</td>
#       <td id="T_ac8be_row0_col2" class="data row0 col2" >1.0571</td>
#       <td id="T_ac8be_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_ac8be_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_ac8be_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 4
# <style type="text/css">
# </style>
# <table id="T_5051c" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5051c_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_5051c_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_5051c_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_5051c_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_5051c_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_5051c_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5051c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5051c_row0_col0" class="data row0 col0" >0.3461</td>
#       <td id="T_5051c_row0_col1" class="data row0 col1" >17.4754</td>
#       <td id="T_5051c_row0_col2" class="data row0 col2" >1.0571</td>
#       <td id="T_5051c_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_5051c_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_5051c_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 5
# <style type="text/css">
# </style>
# <table id="T_f0f96" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f0f96_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_f0f96_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_f0f96_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_f0f96_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_f0f96_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_f0f96_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f0f96_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f0f96_row0_col0" class="data row0 col0" >0.3461</td>
#       <td id="T_f0f96_row0_col1" class="data row0 col1" >17.4754</td>
#       <td id="T_f0f96_row0_col2" class="data row0 col2" >1.0571</td>
#       <td id="T_f0f96_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_f0f96_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_f0f96_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
